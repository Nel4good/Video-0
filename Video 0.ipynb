# %% [markdown]
# # Drugs Discovery using Machine Learning with Festus
#
# # Video 0
#
# Welcome & Setup – Your Toolkit for ML in Drug Discovery
#
# Explanation Script: "Hi everyone! Welcome to my TikTok series where we'll learn how to apply Machine Learning to drug discovery – from zero to hero. Before we dive in, let's set up the tools you'll need. You need Python (I recommend installing via Anaconda), Jupyter Notebook (comes with Anaconda), and three key libraries:
#
# rdkit for handling molecules
#
# pandas for data manipulation
#
# scikit-learn for machine learning
#
# Open your terminal (or Anaconda Prompt) and type the following commands to install them: conda install -c conda-forge rdkit pandas scikit-learn (If you prefer pip, use: pip install rdkit-pypi pandas scikit-learn) Now let's test that everything works. Open Jupyter Notebook, create a new notebook, and run this code:"

# %%
# Install required libraries (run this once)
import rdkit
import pandas as pd
import sklearn
import matplotlib

print("RDKit version:", rdkit.__version__)
print("Pandas version:", pd.__version__)
print("Scikit-learn version:", sklearn.__version__)
print("Matplotlib version:", matplotlib.__version__)

 # Quick RDKit test
from rdkit import Chem
from rdkit.Chem import Draw

mol = Chem.MolFromSmiles('CCO') # ethanol
print("Molecule created:", mol) # This will display the molecule
Draw.MolToImage(mol)
# Out:
# RDKit version: 2025.09.6
# Pandas version: 2.3.3
# Scikit-learn version: 1.7.2
# Matplotlib version: 3.10.8
# Molecule created: <rdkit.Chem.rdchem.Mol object at 0x0000015462E1CF90>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
